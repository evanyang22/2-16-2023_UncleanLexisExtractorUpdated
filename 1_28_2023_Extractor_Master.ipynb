# %%
import os,sys,subprocess
import tempfile
from fuzzywuzzy import fuzz
PDFTOTEXT_PATH="C:\\Users\\evany_cdhq038\\OneDrive\\Desktop\\Economics_Research\\xpdf-tools-win-4.03\\bin64\\pdftotext.exe"

results=[]
completeARList=[]
completeDRList=[]
for fileName in os.scandir():
        if fileName.is_file() and fileName.name.endswith(".pdf"):
            addThis={}
            addThis["PDFName"]=fileName.name
            print(fileName.name)
            
            pdfPath=fileName.path
            #getting -layout version and storing as pdfTextLayout
            try:
                q = subprocess.Popen([PDFTOTEXT_PATH,'-layout',pdfPath,"-"], stdout=subprocess.PIPE, stderr=subprocess.PIPE) 
                pdfTextLayout, err = q.communicate()
            except:
                print('pdftotext Layout failed')
            #getting -table version and storign as pdfTextTable
            try:
                q = subprocess.Popen([PDFTOTEXT_PATH,'-layout',pdfPath,"-"], stdout=subprocess.PIPE, stderr=subprocess.PIPE) 
                pdfTextTable, err = q.communicate()
            except:
                print('pdftotext Table failed')
                
            #writing a tempfile for bot _table and _layout format
            #this is because the old code is based off of f.readlines()
            f = tempfile.TemporaryFile()
            try:
                f.write(pdfTextLayout)
                f.seek(0)
                encodedlineArray=f.readlines() #lineArray is -layout format and what we will be extracting primarily from
            except:
                print("Temp file creation for Layout error")
            finally:
                f.close()
            
            g=tempfile.TemporaryFile()
            try:
                g.write(pdfTextTable)
                g.seek(0)
                encodedtableFile=g.readlines()
            except:
                print("Temp file creation for Table error")
            finally:
                g.close()
            
            #decoding both from bytes to string- might need some modifications bc of latin1 decoding
            lineArray=[]
            tableFile=[]
            for line in encodedlineArray:
                lineArray.append(line.decode("Latin1"))
                
            for line in encodedtableFile:
                tableFile.append(line.decode("Latin1"))
                
            
            #extraction process below
            
            #Extracts gender
            counter=0
            while counter<len(lineArray):
                if("Gender" in lineArray[counter]):
                    if("DOB" in lineArray[counter]):
                        gender=lineArray[counter+1][lineArray[counter].find("Gender"):lineArray[counter].find("LexID")]
                        addThis["Gender"]= gender
                counter=counter+1
            
            #extracts SSN by alternate method through voter registration
            SSNCounter=0
            RegistrantLine=0
            VoterLine=0
            while SSNCounter<len(lineArray):
                if("Registrant Information" in lineArray[SSNCounter]):
                    RegistrantLine=SSNCounter
                if("Voter Information" in lineArray[SSNCounter]):
                    VoterLine=SSNCounter
                SSNCounter+=1
            newLoop=RegistrantLine
            while(newLoop<=VoterLine):
                if("SSN" in lineArray[newLoop]):
                    SSN=lineArray[newLoop][lineArray[newLoop].find(":")+1:]
                    addThis["SSN"]=SSN.strip()
                newLoop+=1
            
            #extracts emails
            emailMax=6
            emailCounter=0
            while emailCounter<len(lineArray):
                if("Email" in lineArray[emailCounter]):
                    if("SSN" in lineArray[emailCounter]):
                        i=1
                        while i<=emailMax:
                            emailNum= "Email"+str(i)
                            emailHolder=lineArray[emailCounter+i][lineArray[emailCounter].find("Email"):]
                            if(emailHolder[-1:] == "\n"):
                                emailHolder=emailHolder[:-1]
                            addThis[emailNum]=emailHolder
                            i=i+1
                emailCounter=emailCounter+1
            
            #extracts date of birth month and year 
            DOBcounter=0
            while DOBcounter<len(lineArray):
                if("DOB" in lineArray[DOBcounter]):
                    if("SSN" in lineArray[DOBcounter] and "Gender" in lineArray[DOBcounter]):
                        DOB=lineArray[DOBcounter+2][lineArray[DOBcounter].find("DOB"):lineArray[DOBcounter].find("Gender")]
                DOBcounter=DOBcounter+1
            DOBMonth=DOB[:DOB.find("/")]
            DOBYear=DOB[DOB.find("/")+1:]
            addThis["DOBMonth"]=DOBMonth
            addThis["DOBYear"]=DOBYear.strip()
            
            #extracts lexID
            IDCounter=0
            while IDCounter<len(tableFile):
                if("LexID" in tableFile[IDCounter]):
                    if("Email" in tableFile[IDCounter]):
                        lexID=tableFile[IDCounter+2][tableFile[IDCounter].find("LexID"):tableFile[IDCounter].find("Email")]
                        addThis["LexID"]=lexID.strip()
                IDCounter=IDCounter+1
            
            #Extracting current address and county
            endCounter=0
            endpoint=0
            while endCounter<len(lineArray):
                if("ADDITIONAL PERSONAL INFORMATION" in lineArray[endCounter]):
                    endpoint=endCounter
                endCounter+=1
            addyCounter=0
            while addyCounter<len(lineArray):
                if("Address" in lineArray[addyCounter]):
                    if("County" in lineArray[addyCounter] and "Phone" in lineArray[addyCounter]):
                        a=1
                        currentAddress=''
                        b=endpoint-addyCounter-1
                        lineCounter=0
                        while a <= b: 
                            currentAddress+=lineArray[addyCounter+a][lineArray[addyCounter].find("Address"):lineArray[addyCounter].find("County")].strip()
                            if lineArray[addyCounter+a][lineArray[addyCounter].find("Address"):lineArray[addyCounter].find("County")].strip() != '':
                                currentAddress+=" "
                                lineCounter+=1
                                if "COUNTY" in lineArray[addyCounter+a]:
                                    addThis["County"]=lineArray[addyCounter+a][lineArray[addyCounter].find("Address"):lineArray[addyCounter].find("County")].strip()
                            a+=1
                addyCounter+=1
            try:
                addThis["CurrentAddress"]= currentAddress.replace(addThis["County"],"").strip()
            except:
                print("No COUNTY for "+  fileName.name)
            #extracts phone number
            phoneCounter=0
            while phoneCounter<len(lineArray):
                if("Phone" in lineArray[phoneCounter]):
                    if("County" in lineArray[phoneCounter] and "Address" in lineArray[phoneCounter]): #makes sure it is the beginning record page
                        phoneNum=lineArray[phoneCounter+1][lineArray[phoneCounter].find("Phone"):]
                phoneCounter=phoneCounter+1
            addThis["PhoneNumber"]=phoneNum.strip()
            
            #extracting name
            addThis["FirstName"]=addThis["PDFName"][:addThis["PDFName"].find("_")].strip()
            addThis["LastName"]=addThis["PDFName"][addThis["PDFName"].find("_")+1:-4].strip()
            addThis["FullName"]=addThis["FirstName"]+' ' + addThis["LastName"]
            
            #extracts property addresses and date range section
            addressCounter=0
            while addressCounter<len(tableFile):
                if("Address Summary" in tableFile[addressCounter]):
                    numAddresses=tableFile[addressCounter][tableFile[addressCounter].find("-")+1:tableFile[addressCounter].find("records")]
                    numAddresses=int(numAddresses)
                addressCounter+=1
            beginCounter=0
            startPoint=0
            while beginCounter<len(tableFile):
                if("Address Details" in tableFile[beginCounter]):
                    startPoint=beginCounter
                beginCounter+=1
            k=1
            searchThis=str(k)+":"
            addyArray=[]
            dateArray=[]
            while startPoint<len(tableFile):
                if searchThis in tableFile[startPoint]:
                    addressHolder=tableFile[startPoint][2:]
                    if("Dates" in addressHolder):
                        addressHolder=addressHolder[:addressHolder.find("Dates")]
                    addressHolder=addressHolder.replace("  ",' ')
                    addressHolder=addressHolder.replace("  ",' ')
                    addressHolder=addressHolder.replace("  ",' ')
                    addressHolder=addressHolder.replace("  ",' ')
                    addressHolder=addressHolder.replace("  ",' ')
                    addressHolder=addressHolder.replace("  ",' ')
                    addressHolder=addressHolder.replace("  ",' ')
                    addressHolder=addressHolder.replace("  ",' ')  
                    addressHolder=addressHolder.replace("  ",' ')
                    addressHolder=addressHolder.replace("  ",' ')
                    addressHolder=addressHolder.replace("  ",' ')
                    addressHolder=addressHolder.replace("  ",' ')
                    addyArray.append(addressHolder.strip())
                    k+=1
                    if k>numAddresses:
                        k='null'
                    searchThis=str(k)+":"
            
                if("Dates" in tableFile[startPoint] and "Phone" in tableFile[startPoint]):
                    dateRange=tableFile[startPoint+2][tableFile[startPoint].find("Dates"):tableFile[startPoint].find("Phone")] #goes down one line and takes date range, might be blank
                    dateArray.append(dateRange.strip())
        
                startPoint+=1
            e=0
            addressRangeList=[]
            while e<len(addyArray):
                holdingDict={}
                holdingDict["PropertyAddress"]=addyArray[e].replace(":","").strip()
                holdingDict["PropertyAddress"]=holdingDict["PropertyAddress"].strip()
                try:
                    holdingDict["DateRange"]=dateArray[e]
                except:
                    print("DateRange error on "+ fileName.name)
                addressRangeList.append(holdingDict)
                e+=1
            fullAnalystAddressList=[]
            for tempDict in addressRangeList:
                tempHolder={**addThis,**tempDict}
                fullAnalystAddressList.append(tempHolder)
            
            results=results + fullAnalystAddressList
    
             #Assessment Record and Deed Record Section
            tempCounter=0
            assessmentStart=0
            assessmentEnd=0
    
            firstInstance=True
            firstEndInstance=True
            while tempCounter < len(lineArray):
                if("Assessment Record" in lineArray[tempCounter] or "Deed Record" in lineArray[tempCounter]):
                    if firstInstance: 
                        assessmentStart=tempCounter
                        firstInstance= False
                tempCounter+=1
            tempCounter=0
            while tempCounter < len(lineArray):
                if("Boats - " in lineArray[tempCounter] or "Potential Relatives -" in lineArray[tempCounter]):
                    if firstEndInstance and tempCounter>assessmentStart:
                        assessmentEnd=tempCounter
                        firstEndInstance= False
                tempCounter+=1
            
            recordDict={}
            i=1
            assessmentRecords=[]
            deedRecords=[]
            count=assessmentStart
            search=str(i)+ ":"
            while count<assessmentEnd:
                if(search in lineArray[count]):
                    if(lineArray[count][lineArray[count].find(search)+2:lineArray[count].find("Record")].strip()=="Assessment"):
                        #assessment records
                        addThis2={} 
                        endpoint=count+1
                        while lineArray[endpoint].find("Record for")==-1 and lineArray[endpoint].find("Boat")==-1 and lineArray[endpoint].find("Potential Relatives")==-1:# returns -1 if not found, loops until it finds "Record for"
                            endpoint+=1
                        recordDict["Assessment"+str(search)]=[]
                        temp=count
                        while temp<endpoint:
                            if("Address" in lineArray[temp]):
                                addThis2["ARAddress"]=lineArray[temp][lineArray[temp].find(":")+1:].strip()
                            if("County" in lineArray[temp]):
                                addThis2["ARCounty"]=lineArray[temp][lineArray[temp].find(":")+1:].strip()
                            if("Recording Date" in lineArray[temp]):
                                addThis2["ARRecordingDate"]=lineArray[temp][lineArray[temp].find(":")+1:].strip()
                            if("Sale Date" in lineArray[temp]):
                                addThis2["ARSaleDate"]=lineArray[temp][lineArray[temp].find(":")+1:].strip()
                            if("Sale Price" in lineArray[temp]):
                                addThis2["ARSalePrice"]=lineArray[temp][lineArray[temp].find(":")+1:].strip()
                            if("Assessed Value" in lineArray[temp]):
                                addThis2["ARAssessedValue"]=lineArray[temp][lineArray[temp].find(":")+1:].strip()
                            if("Market Land Value" in lineArray[temp]):
                                addThis2["ARMarketLandValue"]=lineArray[temp][lineArray[temp].find(":")+1:].strip()
                            if("Market Improvement Value" in lineArray[temp]):
                                addThis2["ARMarketImprovementValue"]= lineArray[temp][lineArray[temp].find(":")+1:].strip()
                            if("Total Market Value" in lineArray[temp]):
                                addThis2["ARTotalMarketValue"]=lineArray[temp][lineArray[temp].find(":")+1:].strip()
                            temp+=1      
                        assessmentRecords.append(addThis2)
                    if(lineArray[count][lineArray[count].find(search)+2:lineArray[count].find("Record")].strip()=="Deed"):
                        addThis3={}
                        endpoint=count+1
                        while(lineArray[endpoint].find("Record for")==-1 and lineArray[endpoint].find("Boat")==-1 and lineArray[endpoint].find("Potential Relatives")==-1):# returns -1 if not found, loops until it finds "Record for"
                            endpoint+=1
                        recordDict["Deed"+str(search)]=[]
                        temp=count
                        while temp<endpoint:
                            if("Address" in lineArray[temp]):
                                addThis3["DRAddress"]=lineArray[temp][lineArray[temp].find(":")+1:].strip()
                            if("Contract Date" in lineArray[temp]):
                                addThis3["DRContractDate"]=lineArray[temp][lineArray[temp].find(":")+1:].strip()
                            if("Recording Date" in lineArray[temp]):
                                addThis3["DRRecordingDate"]=lineArray[temp][lineArray[temp].find(":")+1:].strip()
                            if("Loan Amount" in lineArray[temp]):
                                addThis3["DRLoanAmount"]=lineArray[temp][lineArray[temp].find(":")+1:].strip()
                            if("Loan Type" in lineArray[temp]):
                                addThis3["DRLoanType"]=lineArray[temp][lineArray[temp].find(":")+1:].strip()
                            if("Title Company" in lineArray[temp]):
                                addThis3["DRTitleCompany"]=lineArray[temp][lineArray[temp].find(":")+1:].strip()
                            if("Transaction Type" in lineArray[temp]):
                                addThis3["DRTransactionType"]=lineArray[temp][lineArray[temp].find(":")+1:].strip()
                            if("Description" in lineArray[temp]):
                                addThis3["DRDescription"]=lineArray[temp][lineArray[temp].find(":")+1:].strip()
                            if("Lender Information" in lineArray[temp]):
                                addThis3["DRLenderInformation"]=lineArray[temp+1].find(":")+1
                            temp+=1
                        deedRecords.append(addThis3)
                    i+=1
                    search=str(i)+":"
                count+=1
            cleanAR=[]
            cleanDR=[]

            a=0
            while a<len(assessmentRecords):
                base=assessmentRecords[a]
                b=a+1
                while b<len(assessmentRecords)-a:
                    comparison=assessmentRecords[b]
                    ratio=fuzz.ratio(base["ARAddress"].lower(),comparison["ARAddress"].lower())
                    if(ratio>80): #levenhstein ration >80
                        agregaEsto={**base,**comparison}
                        cleanAR.append(agregaEsto)
                    b+=1
                a+=1
            a=0
            while a<len(deedRecords):
                base=deedRecords[a]
                b=a+1
                while b<len(deedRecords)-a:
                    comparison=deedRecords[b]
                    ratio=fuzz.ratio(base["DRAddress"].lower(),comparison["DRAddress"].lower())
                    if(ratio>80): #levenhstein ration >80
                        agregaEsto={**base,**comparison}
                        cleanDR.append(agregaEsto)
                    b+=1
                a+=1
            if(len(cleanAR)==0):
                cleanAR=assessmentRecords
            if(len(cleanDR)==0):
                cleanDR=deedRecords
    
            for thing in cleanAR:
                addAR={**addThis,**thing}
                completeARList.append(addAR)
            
            for thing in cleanDR:
                addDR={**addThis,**thing}
                completeDRList.append(addDR)
# Out:
# Aaron_Freedman.pdf
# Alan_Murray.pdf
# DateRange error on Alan_Murray.pdf
# Alejandro_Olivo.pdf
# DateRange error on Alejandro_Olivo.pdf
# DateRange error on Alejandro_Olivo.pdf
# Alexander_Yavorsky.pdf
# No COUNTY for Alexander_Yavorsky.pdf
# Alexandra_Parker.pdf
# No COUNTY for Alexandra_Parker.pdf
# Alina_Khavulya.pdf
# Allen_Tischler.pdf
# DateRange error on Allen_Tischler.pdf
# Anastasija_Johnson.pdf
# Andrew_Forsyth.pdf
# Andrew_MacDonald.pdf
# Andrew_Oram.pdf
# DateRange error on Andrew_Oram.pdf
# Angela_Burriesci.pdf
# DateRange error on Angela_Burriesci.pdf
# Angela_Jameson.pdf
# Angelo_Sabatelle.pdf
# DateRange error on Angelo_Sabatelle.pdf
# DateRange error on Angelo_Sabatelle.pdf
# Aniello_Infante.pdf
# Anna_Sherbakova.pdf
# DateRange error on Anna_Sherbakova.pdf
# DateRange error on Anna_Sherbakova.pdf
# DateRange error on Anna_Sherbakova.pdf
# Anna_Zubets-Anderson.pdf
# Anthony_Hill.pdf
# Arif_Bekiroglu.pdf
# Arlene_Isaacs-Lowe.pdf
# DateRange error on Arlene_Isaacs-Lowe.pdf
# DateRange error on Arlene_Isaacs-Lowe.pdf
# DateRange error on Arlene_Isaacs-Lowe.pdf
# DateRange error on Arlene_Isaacs-Lowe.pdf
# Arthur_Fliegelman.pdf
# DateRange error on Arthur_Fliegelman.pdf
# Arvinder_Saluja.pdf
# DateRange error on Arvinder_Saluja.pdf
# DateRange error on Arvinder_Saluja.pdf
# DateRange error on Arvinder_Saluja.pdf
# Ashley_Staropoli.pdf
# Austin_Custodio.pdf
# DateRange error on Austin_Custodio.pdf
# Austin_Langer.pdf
# DateRange error on Austin_Langer.pdf
# Barry_Wadler.pdf
# No COUNTY for Barry_Wadler.pdf
# Bart_Oosterveld.pdf
# Bob_Garofalo.pdf
# No COUNTY for Bob_Garofalo.pdf
# Botir_Sharapov.pdf
# Brian_Oak.pdf
# Brian_Silver.pdf
# DateRange error on Brian_Silver.pdf
# Brian_Weddington.pdf
# DateRange error on Brian_Weddington.pdf
# Bruce_Clark.pdf
# Bruce_Herskovics.pdf
# Calyn_Gelinas.pdf
# DateRange error on Calyn_Gelinas.pdf
# DateRange error on Calyn_Gelinas.pdf
# Carl_Salas.pdf
# Catherine_Guinee.pdf
# No COUNTY for Catherine_Guinee.pdf
# Cecilia_Lam.pdf
# Charles_O&#39Shea.pdf
# DateRange error on Charles_O&#39Shea.pdf
# Charles_O_Shea.pdf
# DateRange error on Charles_O_Shea.pdf
# Charles_Tan.pdf
# DateRange error on Charles_Tan.pdf
# DateRange error on Charles_Tan.pdf
# Chedley_Louis.pdf
# Cheryl_Solometo.pdf
# Chetan_Modi.pdf
# Christian_Azzi.pdf
# Christina_padgett.pdf
# Christopher_O&#39Neil.pdf
# DateRange error on Christopher_O&#39Neil.pdf
# DateRange error on Christopher_O&#39Neil.pdf
# DateRange error on Christopher_O&#39Neil.pdf
# DateRange error on Christopher_O&#39Neil.pdf
# DateRange error on Christopher_O&#39Neil.pdf
# DateRange error on Christopher_O&#39Neil.pdf
# DateRange error on Christopher_O&#39Neil.pdf
# DateRange error on Christopher_O&#39Neil.pdf
# DateRange error on Christopher_O&#39Neil.pdf
# DateRange error on Christopher_O&#39Neil.pdf
# Christophe_Razaire.pdf
# DateRange error on Christophe_Razaire.pdf
# DateRange error on Christophe_Razaire.pdf
# Chris_Park.pdf
# DateRange error on Chris_Park.pdf
# Chris_Wimmer (1).pdf
# DateRange error on Chris_Wimmer (1).pdf
# DateRange error on Chris_Wimmer (1).pdf
# Chris_Wimmer.pdf
# DateRange error on Chris_Wimmer.pdf
# DateRange error on Chris_Wimmer.pdf
# Cintia_Nazima.pdf
# Clifford_Crain.pdf
# Constanze_Rheinbaben.pdf
# Costas_Chrysostomou.pdf
# Craig_Emrick.pdf
# Daniel_Gates.pdf
# Daniel_Greszta.pdf
# Daniel_Marx.pdf
# Daniel_Serrao.pdf
# DateRange error on Daniel_Serrao.pdf
# David_Berge.pdf
# DateRange error on David_Berge.pdf
# David_Fanger (1).pdf
# David_Fanger.pdf
# David_Hamburger.pdf
# David_Kamran.pdf
# David_Keisman.pdf
# DateRange error on David_Keisman.pdf
# DateRange error on David_Keisman.pdf
# DateRange error on David_Keisman.pdf
# David_Neuhaus.pdf
# No COUNTY for David_Neuhaus.pdf
# Dean_Ungar.pdf
# Deborah_Schuler.pdf
# DateRange error on Deborah_Schuler.pdf
# DateRange error on Deborah_Schuler.pdf
# DateRange error on Deborah_Schuler.pdf
# Denise_Rappmund.pdf
# DateRange error on Denise_Rappmund.pdf
# DateRange error on Denise_Rappmund.pdf
# Dennis_Saputo.pdf
# Derek_Gluckman.pdf
# Deven_Kapoor.pdf
# Deven_Shah.pdf
# No COUNTY for Deven_Shah.pdf
# DateRange error on Deven_Shah.pdf
# Dhruv_Khanna.pdf
# Dilara_Sukhov.pdf
# Domenick_Fumai.pdf
# Dominick_D&#39Ascoli.pdf
# Dylan_Duzey.pdf
# Earl_Heffintrayer.pdf
# Edmond_DeForest.pdf
# Edna_Marinelarena.pdf
# Edward_Schmidt.pdf
# DateRange error on Edward_Schmidt.pdf
# Edward_Young.pdf
# No COUNTY for Edward_Young.pdf
# Elaine_Francolino.pdf
# Emile_El_Nems.pdf
# Emily_Eisenlohr.pdf
# Enam_Hoque.pdf
# Enrico_Leo.pdf
# Eoin_Roche.pdf
# Eric_Greaser.pdf
# Eric_kozlowski.pdf
# Everett_Rutan.pdf
# Farah_Zakir.pdf
# No COUNTY for Farah_Zakir.pdf
# Felipe_Carvallo-Mendoza.pdf
# Fernando_Freijedo.pdf
# Filippe_Goossens.pdf
# DateRange error on Filippe_Goossens.pdf
# Frank_Grbic.pdf
# Fred_Zelaya.pdf
# Gabriel_Hack.pdf
# Gail_Sussman.pdf
# DateRange error on Gail_Sussman.pdf
# Gayle_Podurgiel.pdf
# DateRange error on Gayle_Podurgiel.pdf
# DateRange error on Gayle_Podurgiel.pdf
# DateRange error on Gayle_Podurgiel.pdf
# DateRange error on Gayle_Podurgiel.pdf
# George_Godlin.pdf
# Gerald_Granovsky.pdf
# Giovanni_Velez.pdf
# DateRange error on Giovanni_Velez.pdf
# Glenn_Eckert.pdf
# Grace_Kennedy.pdf
# No COUNTY for Grace_Kennedy.pdf
# DateRange error on Grace_Kennedy.pdf
# Gregory_Bauer.pdf
# DateRange error on Gregory_Bauer.pdf
# Gregory_Frank.pdf
# DateRange error on Gregory_Frank.pdf
# DateRange error on Gregory_Frank.pdf
# Gregory_Reed.pdf
# DateRange error on Gregory_Reed.pdf
# Greg_Bauer.pdf
# DateRange error on Greg_Bauer.pdf
# Gretchen_French.pdf
# Gurkirat_Hans.pdf
# Harmandeep_Saggu.pdf
# DateRange error on Harmandeep_Saggu.pdf
# DateRange error on Harmandeep_Saggu.pdf
# DateRange error on Harmandeep_Saggu.pdf
# Ignacio_Rasero.pdf
# DateRange error on Ignacio_Rasero.pdf
# Imran_Ansari.pdf
# DateRange error on Imran_Ansari.pdf
# Irina_Brooklier.pdf
# Jack_Leyland.pdf
# Jacques_Ouazana.pdf
# DateRange error on Jacques_Ouazana.pdf
# DateRange error on Jacques_Ouazana.pdf
# DateRange error on Jacques_Ouazana.pdf
# Jadijhe_Adamo.pdf
# Jairo_Chung.pdf
# James_Hempstead.pdf
# DateRange error on James_Hempstead.pdf
# DateRange error on James_Hempstead.pdf
# James_O&#39Shaughnessy.pdf
# James_Reilly.pdf
# No COUNTY for James_Reilly.pdf
# DateRange error on James_Reilly.pdf
# James_Veneau.pdf
# No COUNTY for James_Veneau.pdf
# Jane_Cotroneo.pdf
# Janice_Hofferber.pdf
# DateRange error on Janice_Hofferber.pdf
# Jason_Grohotolski.pdf
# DateRange error on Jason_Grohotolski.pdf
# DateRange error on Jason_Grohotolski.pdf
# Jason_Sevier.pdf
# DateRange error on Jason_Sevier.pdf
# DateRange error on Jason_Sevier.pdf
# DateRange error on Jason_Sevier.pdf
# Jason_Tam.pdf
# DateRange error on Jason_Tam.pdf
# Jasper_Cooper.pdf
# DateRange error on Jasper_Cooper.pdf
# Jay_Siegel.pdf
# Jeanne_Casino.pdf
# No COUNTY for Jeanne_Casino.pdf
# Jean_Coupin.pdf
# DateRange error on Jean_Coupin.pdf
# Jeffrey_Berg.pdf
# Jeffrey_Cassella.pdf
# DateRange error on Jeffrey_Cassella.pdf
# Jerome_Fons.pdf
# Jessica_Gladstone.pdf
# DateRange error on Jessica_Gladstone.pdf
# DateRange error on Jessica_Gladstone.pdf
# Jessica_Raab.pdf
# DateRange error on Jessica_Raab.pdf
# Jim_Hempstead.pdf
# Joanna_O_#39Brien.pdf
# Joann_Hempel.pdf
# No COUNTY for Joann_Hempel.pdf
# Joel_Levine.pdf
# DateRange error on Joel_Levine.pdf
# DateRange error on Joel_Levine.pdf
# DateRange error on Joel_Levine.pdf
# Joel_Lustig.pdf
# Joe_Morrison.pdf
# No COUNTY for Joe_Morrison.pdf
# johnathan_root.pdf
# DateRange error on johnathan_root.pdf
# DateRange error on johnathan_root.pdf
# John_Beaudouin.pdf
# John_Dennehy.pdf
# No COUNTY for John_Dennehy.pdf
# John_Grause.pdf
# DateRange error on John_Grause.pdf
# John_Kriz.pdf
# DateRange error on John_Kriz.pdf
# DateRange error on John_Kriz.pdf
# John_Puchalla.pdf
# John_Rogers.pdf
# John_Theiroff.pdf
# DateRange error on John_Theiroff.pdf
# DateRange error on John_Theiroff.pdf
# DateRange error on John_Theiroff.pdf
# Jonathan_Kalmanoff.pdf
# Jonathan_Kanarek.pdf
# Jonathan_Root.pdf
# DateRange error on Jonathan_Root.pdf
# DateRange error on Jonathan_Root.pdf
# DateRange error on Jonathan_Root.pdf
# DateRange error on Jonathan_Root.pdf
# Jonathan_Teitel.pdf
# Joseph_Hury.pdf
# Joseph_Pucella.pdf
# DateRange error on Joseph_Pucella.pdf
# Joseph_Snailer.pdf
# Juan_Acosta.pdf
# DateRange error on Juan_Acosta.pdf
# Julie_Meyer.pdf
# DateRange error on Julie_Meyer.pdf
# Jun_Sakurabayashi.pdf
# Justin_Remsen.pdf
# Kailash_Chhaya.pdf
# Kai_Hu.pdf
# DateRange error on Kai_Hu.pdf
# Karen_Berckmann copy.pdf
# Karen_Berckmann.pdf
# Karen_Nickerson.pdf
# Katelyn_Bayone.pdf
# Katherine_Frey.pdf
# DateRange error on Katherine_Frey.pdf
# Kazusada_Hirose.pdf
# keith_foley.pdf
# Kei_Kitayama.pdf
# Kendra_Smith.pdf
# Kenneth_Austin.pdf
# DateRange error on Kenneth_Austin.pdf
# DateRange error on Kenneth_Austin.pdf
# Kenneth_Emery.pdf
# DateRange error on Kenneth_Emery.pdf
# Kevin_Stoklosa.pdf
# DateRange error on Kevin_Stoklosa.pdf
# DateRange error on Kevin_Stoklosa.pdf
# DateRange error on Kevin_Stoklosa.pdf
# Kevin_Stuebe.pdf
# Kevin_Ziets.pdf
# Kirk_Belinfanti.pdf
# DateRange error on Kirk_Belinfanti.pdf
# Kyle_Goodwin.pdf
# Laura_Levenstein.pdf
# DateRange error on Laura_Levenstein.pdf
# DateRange error on Laura_Levenstein.pdf
# Laura_Schumacher.pdf
# Lauren_Bonham.pdf
# Laurie_Mayers.pdf
# Lee_Zeltser.pdf
# DateRange error on Lee_Zeltser.pdf
# Lenny_Ajzenman.pdf
# Leo_Wah.pdf
# DateRange error on Leo_Wah.pdf
# Lesia_Moss.pdf
# DateRange error on Lesia_Moss.pdf
# DateRange error on Lesia_Moss.pdf
# DateRange error on Lesia_Moss.pdf
# Lesley_Ritter.pdf
# Linda_Montag.pdf
# Linda_Stesney.pdf
# Lisa_Matalon.pdf
# Lori_marks.pdf
# Manish_Desai.pdf
# manoj_chadha.pdf
# Marcus_Jones.pdf
# DateRange error on Marcus_Jones.pdf
# Marc_Abusch.pdf
# Marc_Serafin.pdf
# DateRange error on Marc_Serafin.pdf
# Margaret_Holloway.pdf
# Maria_Iarriccio.pdf
# Maria_Maslovsky.pdf
# Maria_Vansetti (1).pdf
# DateRange error on Maria_Vansetti (1).pdf
# DateRange error on Maria_Vansetti (1).pdf
# DateRange error on Maria_Vansetti (1).pdf
# Maria_Vansetti.pdf
# DateRange error on Maria_Vansetti.pdf
# DateRange error on Maria_Vansetti.pdf
# DateRange error on Maria_Vansetti.pdf
# Marie_Menendez.pdf
# Marina_Ivanov.pdf
# Mark_Alexander.pdf
# DateRange error on Mark_Alexander.pdf
# DateRange error on Mark_Alexander.pdf
# Mark_Gray.pdf
# Mark_Stodden (1).pdf
# DateRange error on Mark_Stodden (1).pdf
# DateRange error on Mark_Stodden (1).pdf
# Mark_Stodden.pdf
# DateRange error on Mark_Stodden.pdf
# DateRange error on Mark_Stodden.pdf
# Mark_Vassilakis.pdf
# DateRange error on Mark_Vassilakis.pdf
# DateRange error on Mark_Vassilakis.pdf
# DateRange error on Mark_Vassilakis.pdf
# Mark_Wasden.pdf
# No COUNTY for Mark_Wasden.pdf
# MATTHEW_Kuchtyak.pdf
# Matthew_Musicaro.pdf
# Merrie_Frankel.pdf
# Michael_Corelli (1).pdf
# DateRange error on Michael_Corelli (1).pdf
# Michael_Corelli.pdf
# DateRange error on Michael_Corelli.pdf
# Michael_Doss.pdf
# Michael_Fruchter.pdf
# Michael_Haggarty.pdf
# DateRange error on Michael_Haggarty.pdf
# DateRange error on Michael_Haggarty.pdf
# Michael_Labuskes.pdf
# Michael_Levesque.pdf
# Michael_Mascarenhas.pdf
# DateRange error on Michael_Mascarenhas.pdf
# Michael_Mulvaney copy.pdf
# Michael_Mulvaney.pdf
# Michael_Pehota.pdf
# Michael_Zuccaro.pdf
# Mihoko_Manabe.pdf
# Minoru_Kubota.pdf
# Minyan_Liu.pdf
# Min_Ye.pdf
# Mitchell_Moss.pdf
# Mohnish_Pardasani.pdf
# Morris_Borenstein.pdf
# Myra_Shankin.pdf
# DateRange error on Myra_Shankin.pdf
# DateRange error on Myra_Shankin.pdf
# Myriam_Durand.pdf
# DateRange error on Myriam_Durand.pdf
# DateRange error on Myriam_Durand.pdf
# Nana_Hamilton.pdf
# Nancy_Meadows.pdf
# DateRange error on Nancy_Meadows.pdf
# Naomi_Richman.pdf
# Natalia_Gluschuck.pdf
# Neal_Epstein.pdf
# DateRange error on Neal_Epstein.pdf
# Neil_Begley.pdf
# Neil_Mack.pdf
# Nicholas_Krasno.pdf
# Nicholas_Levidy.pdf
# Nick_Levidy.pdf
# Olga_Khodosh.pdf
# Oliver_Alcantara.pdf
# Otavio_Caproni.pdf
# Panayotis_Karambelas.pdf
# Patrick_Blake.pdf
# Patrick_Mispagel.pdf
# DateRange error on Patrick_Mispagel.pdf
# DateRange error on Patrick_Mispagel.pdf
# DateRange error on Patrick_Mispagel.pdf
# Patrick_Winsbury.pdf
# Paul_Aran.pdf
# DateRange error on Paul_Aran.pdf
# DateRange error on Paul_Aran.pdf
# Peggy_Holloway.pdf
# Peter_Abdill copy.pdf
# Peter_Abdill.pdf
# DateRange error on Peter_Abdill.pdf
# Peter_Nerby copy.pdf
# Peter_Nerby.pdf
# Philip_Emma.pdf
# Philip_Guarco.pdf
# Prateek_Reddy.pdf
# DateRange error on Prateek_Reddy.pdf
# Raj_Joshi.pdf
# DateRange error on Raj_Joshi.pdf
# Randy_Matlosz.pdf
# Ranjini_Venkatesan.pdf
# Raya_Sokolyanska.pdf
# Reed_Valutas.pdf
# Rehan_Akbar.pdf
# DateRange error on Rehan_Akbar.pdf
# Rene_Lipsch.pdf
# Renier_Lipsch.pdf
# Richard_Bittenbender.pdf
# DateRange error on Richard_Bittenbender.pdf
# DateRange error on Richard_Bittenbender.pdf
# DateRange error on Richard_Bittenbender.pdf
# DateRange error on Richard_Bittenbender.pdf
# Rita_Sahu.pdf
# Robert_Donohue.pdf
# Robert_Jankowitz copy.pdf
# Robert_Jankowitz.pdf
# Robert_Konefal.pdf
# Robert_Petrosino.pdf
# Robert_Ray.pdf
# Roy_Ousley.pdf
# Russell_Pomerantz.pdf
# Russell_Solomon (1).pdf
# Russell_Solomon.pdf
# Ryan_O&#39Connell.pdf
# DateRange error on Ryan_O&#39Connell.pdf
# Ryan_Wobbrock copy.pdf
# Ryan_Wobbrock.pdf
# Safat_Hannan.pdf
# Sajjad_Alam.pdf
# Saulat_Sultan.pdf
# DateRange error on Saulat_Sultan.pdf
# Scott_Manduca.pdf
# No COUNTY for Scott_Manduca.pdf
# Scott_Solomon copy.pdf
# Scott_Solomon.pdf
# Scott_Tuhy copy 2.pdf
# Scott_Tuhy copy.pdf
# DateRange error on Scott_Tuhy copy.pdf
# Scott_Tuhy.pdf
# Serge_Krukovsky.pdf
# Shachar_Gonen.pdf
# Shilpa_Parandekar.pdf
# Sidharth_Thakur.pdf
# Sreedhar_Kona.pdf
# DateRange error on Sreedhar_Kona.pdf
# Stanislas_Rouyer.pdf
# Stathis_Kyriakides.pdf
# Stefan_Kahandaliyanage.pdf
# Stephen_Gutkowski.pdf
# Stephen_Morrison.pdf
# DateRange error on Stephen_Morrison.pdf
# Steven_Hess.pdf
# DateRange error on Steven_Hess.pdf
# Steven_Oman.pdf
# DateRange error on Steven_Oman.pdf
# Susana_Vivares.pdf
# DateRange error on Susana_Vivares.pdf
# DateRange error on Susana_Vivares.pdf
# DateRange error on Susana_Vivares.pdf
# Suzanne_Wingo copy.pdf
# DateRange error on Suzanne_Wingo copy.pdf
# DateRange error on Suzanne_Wingo copy.pdf
# DateRange error on Suzanne_Wingo copy.pdf
# Suzanne_Wingo.pdf
# DateRange error on Suzanne_Wingo.pdf
# DateRange error on Suzanne_Wingo.pdf
# DateRange error on Suzanne_Wingo.pdf
# Sydney_Kyne.pdf
# Tadashi_Usui.pdf
# Taimur_Jamil.pdf
# DateRange error on Taimur_Jamil.pdf
# DateRange error on Taimur_Jamil.pdf
# DateRange error on Taimur_Jamil.pdf
# Takahiro_Morita.pdf
# DateRange error on Takahiro_Morita.pdf
# DateRange error on Takahiro_Morita.pdf
# Thomas_Brigandi.pdf
# Thomas_Coleman (1).pdf
# Thomas_Coleman.pdf
# DateRange error on Thomas_Coleman.pdf
# Thomas_Marshella.pdf
# Tiina_Siilaberg.pdf
# DateRange error on Tiina_Siilaberg.pdf
# DateRange error on Tiina_Siilaberg.pdf
# Timothy_Harrod.pdf
# DateRange error on Timothy_Harrod.pdf
# DateRange error on Timothy_Harrod.pdf
# DateRange error on Timothy_Harrod.pdf
# Timour_Boudkeev.pdf
# Tobias_Lewis.pdf
# DateRange error on Tobias_Lewis.pdf
# DateRange error on Tobias_Lewis.pdf
# DateRange error on Tobias_Lewis.pdf
# Toby_Shea.pdf
# Todd_Robinson.pdf
# Tommy_Stodolski.pdf
# Venkat_Bogavelli.pdf
# Vincent_Gatto.pdf
# No COUNTY for Vincent_Gatto.pdf
# DateRange error on Vincent_Gatto.pdf
# Vladimir_Ronin.pdf
# Walter_Winrow.pdf
# DateRange error on Walter_Winrow.pdf
# Warren_Kornfeld.pdf
# Wesley_Coggins.pdf
# William_May.pdf
# DateRange error on William_May.pdf
# DateRange error on William_May.pdf
# DateRange error on William_May.pdf
# DateRange error on William_May.pdf
# Wolfgang_Draack.pdf
# Yasmine_Grossenbacher.pdf
# Yoshio_Takahashi.pdf
# DateRange error on Yoshio_Takahashi.pdf
# DateRange error on Yoshio_Takahashi.pdf
# Yves_Lemay.pdf
# Zev_Halstuch.pdf

# %%
#cleaning section for property addresses
#remove dates and phone numbers
import re
cleanedPropertyAddresses=[]
for uncleanAddy in results:
    zipMatch=re.search('.*\s\d{5}(-\d{4})?',uncleanAddy["PropertyAddress"])
    if zipMatch is not None:
        #print(uncleanAddy["PropertyAddress"] +"  ====cleaned to====  "+ uncleanAddy["PropertyAddress"][:zipMatch.end()].strip())
        remainder =uncleanAddy["PropertyAddress"][zipMatch.end():].strip()
        if "(" in remainder:
            uncleanAddy["PhoneNumber"]=remainder[remainder.find("("):]
            uncleanAddy["DateRange"]= remainder[:remainder.find("(")]
        else:
            #phoneMatch=re.search('.*\s\d{3}-\d{4}?',remainder)
            #if phoneMatch is not None:
                #print(phoneMatch.end())
                #print(remainder[phoneMatch.start():])
                #print(remainder[:phoneMatch.start()])
             #   uncleanAddy["PhoneNumber"]= remainder[phoneMatch.end():]
              #  uncleanAddy["DateRange"]= remainder[:phoneMatch.end()]
            uncleanAddy["DateRange"] =uncleanAddy["PropertyAddress"][zipMatch.end():].strip()
        
        uncleanAddy["PropertyAddress"]=uncleanAddy["PropertyAddress"][:zipMatch.end()].strip()

# %%
import csv
csv_columns=["PDFName", "FullName", "FirstName", "LastName","County","PhoneNumber","SSN","DOBMonth","DOBYear","Gender","LexID","Email1","Email2","Email3","Email4","Email5","Email6","CurrentAddress","PropertyAddress","DateRange"]
AR_columns=["ARAddress","ARCounty","ARRecordingDate","ARSaleDate","ARSalePrice","ARAssessedValue","ARMarketLandValue","ARMarketImprovementValue","ARTotalMarketValue"]
DR_columns=["DRAddress","DRContractDate","DRRecordingDate","DRLoanAmount","DRLoanType","DRTitleCompany","DRTransactionType","DRDescription","DRLenderInformation"]
all_columns=csv_columns+AR_columns+DR_columns

masterList=[]

for addyDict in results:
    mergeThis={}
    for ARDict in completeARList:
        tempRatio= fuzz.ratio(ARDict["ARAddress"].lower().strip(),addyDict["PropertyAddress"].lower().strip())
        if tempRatio> 90:
            addyDict={**addyDict,**ARDict} 
            
    for DRDict in completeDRList:
        holdingRatio= fuzz.ratio(DRDict["DRAddress"].lower().strip(),addyDict["PropertyAddress"].lower().strip())
        if holdingRatio>90:
            addyDict={**addyDict,**DRDict}
    
    masterList.append(addyDict)
    
    
csv_file="2_13_Moody.csv"
masterList=sorted(masterList,key=lambda x: x['FirstName'])
    
try:
    with open(csv_file,'w',newline="") as csvfile:
        writer=csv.DictWriter(csvfile,fieldnames=all_columns)
        writer.writeheader()
        for data in masterList:
            writer.writerow(data)
except IOError:
    print("IOError")
